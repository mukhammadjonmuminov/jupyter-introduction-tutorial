# %% [markdown]
#  # Introduction to Jupyter Notebook
# <img src="cat.jpeg" align="center"/>

# %%
! pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
plt.plot([0, 1, 2, 3, 4, 5, 6, 7], [0, 1, 4, 9, 16, 25, 36, 49])

# %%
plt.plot(['Yanvar', 'Fevral', 'Mart', 'Aprel'], [1, 4, 9, 16])

# %%
plt.bar(['Yanvar', 'Fevral', 'Mart', 'Aprel'], [1, 4, 9, 16])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(['Yanvar', 'Fevral', 'Mart', 'Aprel'], [1, 4, 9, 16])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(['Yanvar', 'Fevral', 'Mart', 'Aprel'], [1, 4, 9, 16], color='red')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(['Yanvar', 'Fevral', 'Mart', 'Aprel'], [1, 4, 9, 16], color=['red', 'green', 'blue', 'black'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.pie([1, 2, 3, 4])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7035d52880>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])

# %%
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, data=None)>

# %%
plt.pie([26, 45], labels=['Female', 'Male'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7035c89100>,
# ...
#  [Text(0.44889201849321714, 1.0042389933342986, 'Female'),
#   Text(-0.4488920184932173, -1.0042389933342986, 'Male')])
